# %% [markdown]
# This Jupyter Notebook is the a demonstration of Web Scraping in Python. We are tasked with getting a dataset of the top Broadway shows along with their theatre and price. We can compile our dataset using Web Scraping with the help of the Python libraries BeautifulSoup and Json. We can get our information by webscrapping from [www.broadway.com](www.broadway.com).

# %%
#importing libraries


import requests # -> This helps establish a connection to the website
from bs4 import BeautifulSoup
import json # -> This helps with the parsing of specific text on a site
import pandas as pd

# %%
url = "https://www.broadway.com"
response = requests.get(url)
html = response.content
scraped = BeautifulSoup(html, 'html.parser')

# %% [markdown]
# Let's test the reponse below. We want to see a 200. A response of 400 means there is a BAD connection.

# %%
response
# Out:
# <Response [200]>

# %%
#This is all of the text on the website. Now we just have to do some digging.
scraped
# Out:
# <!DOCTYPE html>
#
# <html lang="en" xml:lang="en" xmlns="http://www.w3.org/1999/xhtml" xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://ogp.me/ns#">
# <head>
# <meta charset="utf-8"/>
# <title>Broadway Tickets | Broadway Shows | Theater Tickets | Broadway.com</title>
# <meta content="width=device-width, minimum-scale=0.1, initial-scale=1" name="viewport"/>
# <meta content="The most comprehensive source for Broadway Shows, Broadway Tickets, Off-Broadway, London theater information, Tickets, Gift Certificates, Videos, News &amp; Features, Reviews, Photos." name="description"/>
# <meta content="#25262b" name="msapplication-TileColor"/>
# <meta content="#1f2023" name="theme-color"/>
# <!-- Site Verification -->
# <meta content="10C3133083513657F42058B6E919699D" name="msvalidate.01"/>
# <meta content="b4c96cd61f1e98c1" name="y_key"/>
# <!-- Mixpanel -->
# <script type="text/javascript">
#                 (function(c,a){if(!a.__SV){var b=window;try{var d,m,j,k=b.location,f=k.hash;d=function(a,b){return(m=a.match(RegExp(b+"=([^&]*)")))?m[1]:null};f&&d(f,"state")&&(j=JSON.parse(decodeURIComponent(d(f,"state"))),"mpeditor"===j.action&&(b.sessionStorage.setItem("_mpcehash",f),history.replaceState(j.desiredHash||"",c.title,k.pathname+k.search)))}catch(n){}var l,h;window.mixpanel=a;a._i=[];a.init=function(b,d,g){function c(b,i){var a=i.split(".");2==a.length&&(b=b[a[0]],i=a[1]);b[i]=function(){b.push([i].concat(Array.prototype.slice.call(arguments,
#                 0)))}}var e=a;"undefined"!==typeof g?e=a[g]=[]:g="mixpanel";e.people=e.people||[];e.toString=function(b){var a="mixpanel";"mixpanel"!==g&&(a+="."+g);b||(a+=" (stub)");return a};e.people.toString=function(){return e.toString(1)+".people (stub)"};l="disable time_event track track_pageview track_links track_forms track_with_groups add_group set_group remove_group register register_once alias unregister identify name_tag set_config reset opt_in_tracking opt_out_tracking has_opted_in_tracking has_opted_out_tracking clear_opt_in_out_tracking people.set people.set_once people.unset people.increment people.append people.union people.track_charge people.clear_charges people.delete_user people.remove".split(" ");
#                 for(h=0;h<l.length;h++)c(e,l[h]);var f="set set_once union unset remove delete".split(" ");e.get_group=function(){function a(c){b[c]=function(){call2_args=arguments;call2=[c].concat(Array.prototype.slice.call(call2_args,0));e.push([d,call2])}}for(var b={},d=["get_group"].concat(Array.prototype.slice.call(arguments,0)),c=0;c<f.length;c++)a(f[c]);return b};a._i.push([b,d,g])};a.__SV=1.2;b=c.createElement("script");b.type="text/javascript";b.async=!0;b.src="undefined"!==typeof MIXPANEL_CUSTOM_LIB_URL?
#                 MIXPANEL_CUSTOM_LIB_URL:"file:"===c.location.protocol&&"//cdn.mxpnl.com/libs/mixpanel-2-latest.min.js".match(/^\/\//)?"https://cdn.mxpnl.com/libs/mixpanel-2-latest.min.js":"//cdn.mxpnl.com/libs/mixpanel-2-latest.min.js";d=c.getElementsByTagName("script")[0];d.parentNode.insertBefore(b,d)}})(document,window.mixpanel||[]);
#                 mixpanel.init("f4468a5f0cdec7b851e99c76f72ca3dc", { track_links_timeout: 250 });
#             </script>
# <script>
#                 dataLayer = [];
#             </script>
# <!-- Google Tag Manager and Analytics -->
# <script>
#             (function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
#             new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
#             j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
#             '//www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
#             })(window,document,'script','dataLayer','GTM-HRPQ');
#         </script>
# <script>
#             (function() {
#                 var d = document.documentElement;
#                 d.setAttribute('data-useragent', navigator.userAgent);
#             })();
#         </script>
# <link href="https://static.broadway.com/img/responsive/favicons/favicon.8992145d808c.ico" rel="shortcut icon" type="image/x-icon"/>
# <link href="https://static.broadway.com/img/responsive/favicons/apple-touch-icon.f003c455893a.png" rel="apple-touch-icon" sizes="180x180"/>
# <link href="https://static.broadway.com/img/responsive/favicons/manifest.799459f8be68.json" rel="manifest"/>
# <link color="#a91f16" href="https://static.broadway.com/img/responsive/favicons/safari-pinned-tab.123c12a54604.svg" rel="mask-icon"/>
# <link href="https://static.broadway.com/img/responsive/favicons/favicon-32x32.6dbfeff78479.png" rel="icon" sizes="32x32" type="image/png"/>
# <link href="https://static.broadway.com/img/responsive/favicons/favicon-16x16.4b373edbfbd4.png" rel="icon" sizes="16x16" type="image/png"/>
# <link href="https://www.broadway.com/" rel="canonical">
# <link href="/feeds/buzz/latest" rel="alternate" title="RSS" type="application/rss+xml"/>
# <!-- Homepage Meta -->
# <meta content="Broadway.com" property="og:title"/>
# <meta content="website" property="og:type"/>
# <meta content="https://static.broadway.com/img/social/open-graph.7361891572d7.jpg" property="og:image"/>
# <meta content="https://www.broadway.com/" property="og:url"/>
# <meta content="Broadway.com" property="og:site_name"/>
# <meta content="The most comprehensive source for Broadway Shows, Broadway Tickets, Off-Broadway, London theater information, Tickets, Gift Certificates, Videos, News &amp; Features, Reviews, Photos." property="og:description"/>
# <meta content="summary" name="twitter:card">
# <meta content="@broadwaycom" name="twitter:site">
# <meta content="Broadway Tickets | Broadway Shows | Theater Tickets | Broadway.com" name="twitter:title">
# <meta content="summary_large_image" name="twitter:card"/>
# <meta content="https://static.broadway.com/img/responsive/social/bwy-generic-social.ef3d64c1c7c9.jpg" name="twitter:image"/>
# <meta content="The most comprehensive source for Broadway Shows, Broadway Tickets, Off-Broadway Tickets, Gift Certificates, Videos, News; Features, Reviews, and Photos" name="twitter:description"/>
# <script type="application/ld+json">
#                 [{
#                     "@context": "http://schema.org",
#                     "@type": "WebSite",
#                     "name": "Broadway.com",
#                     "url": "https://www.broadway.com",
#                     "potentialAction": {
#                         "@type": "SearchAction",
#                         "target": "https://www.broadway.com/search?q={search_term_string}",
#                         "query-input": "required name=search_term_string"
#                     }
#                 }, {
#                     "@context": "http://schema.org",
#                     "@type": "Organization",
#                     "name": "Broadway.com",
#                     "url": "https://www.broadway.com",
#                     "logo": "https://static.broadway.com/img/responsive/logos/structured_data_Icon-512@3x.bc39fd2effc5.png",
#                     "sameAs": [
#                         "https://www.facebook.com/Broadway",
#                         "https://twitter.com/Broadwaycom",
#                         "https://www.youtube.com/Broadwaycom",
#                         "https://pinterest.com/broadwaycom/",
#                         "https://broadwaycom.tumblr.com/",
#                         "https://instagram.com/broadwaycom"
#                     ]
#                 }]
#             </script>
# <meta content="-dBnQgpOA0c2mT0SoDoaOmq0w1Q2v7Aa560wDoz4SGw" name="google-site-verification">
# <link href="//imaging.broadway.com" rel="dns-prefetch"/>
# <link href="//static.broadway.com" rel="dns-prefetch"/>
# <link href="//ad.doubleclick.net" rel="dns-prefetch"/>
# <!-- Facebook Pixel -->
# <script>
#             !function(f,b,e,v,n,t,s){if(f.fbq)return;n=f.fbq=function(){n.callMethod?
#             n.callMethod.apply(n,arguments):n.queue.push(arguments)};if(!f._fbq)f._fbq=n;
#             n.push=n;n.loaded=!0;n.version='2.0';n.queue=[];t=b.createElement(e);t.async=!0;
#             t.src=v;s=b.getElementsByTagName(e)[0];s.parentNode.insertBefore(t,s)}(window,
#             document,'script','https://connect.facebook.net/en_US/fbevents.js');
#             fbq('init', '682878898465597');
#             fbq('track', 'PageView');
#         </script>
# <script type="text/javascript">
#             var googletag = googletag || {};
#             googletag.cmd = googletag.cmd || [];
#             (function () {
#                 var gads = document.createElement('script');
#                 gads.async = true;
#                 gads.type = 'text/javascript';
#                 var useSSL = 'https:' == document.location.protocol;
#                 gads.src = (useSSL ? 'https:' : 'http:') + '//www.googletagservices.com/tag/js/gpt.js';
#                 var node = document.getElementsByTagName('script')[0];
#                 node.parentNode.insertBefore(gads, node);
#             })();
#         </script>
# <script>
#
#             (function () {
#
#                     var networkCode = 73255505;
#                     var subdomain = 'broadway';
#                     var topLevelAdUnit = subdomain;
#                     var s_values = [];
#
#
#     var s1 = 'home';
#     s_values.push(s1);
#
#
#                     var s_values_str = s_values.join('/');
#
#                     var adUnit = topLevelAdUnit;
#                     if (s_values_str.length) {
#                         adUnit += '/' + s_values_str;
#                     }
#
#                     var slotName = '/' + networkCode;
#                     if (adUnit.length) {
#                         slotName += '/' + adUnit;
#                     }
#
#                     function getQueryVariables(variable) {
#                         var temp, i;
#                         var queryString = window.location.search.substring(1);
#                         var queries = queryString.split('&');
#                         var len = queries.length;
#
#                         for (i = 0; i < len; i++) {
#                             temp = queries[i].split('=');
#                             if (temp[0] === variable) {
#                                 return temp[1];
#                             }
#                         }
#                     }
#                     var type = '';
#                     var breakpoint = '';
#                     var dfp_test = getQueryVariables('dfp_test') || '';
#
#
#                 googletag.cmd.push(function () {
#
#                         googletag.defineSlot(slotName, [111, 12], 'dfp-nav-mastercard-desktop')
#                             .addService(googletag.pubads())
#                             .setTargeting('pos', 'nav-mastercard-desktop')
#                             .setCollapseEmptyDiv(true, true);
#                         googletag.defineSlot(slotName, [111, 12], 'dfp-nav-mastercard-mobile')
#                             .addService(googletag.pubads())
#                             .setTargeting('pos', 'nav-mastercard-mobile')
#                             .setCollapseEmptyDiv(true, true);
#
#
#
#     var dfp_home_a = googletag.sizeMapping()
#         .addSize([992,0], [[970, 90], [970,250]])
#         .addSize([768,0], [728,90])
#         .addSize([0, 0], [320, 50]).build();
#
#     googletag.defineSlot(slotName, [[970, 90], [970,250], [728, 90], [320, 50]], 'dfp-home-a')
#         .defineSizeMapping(dfp_home_a)
#         .addService(googletag.pubads())
#         .setTargeting('pos', 'home-a')
#         .setCollapseEmptyDiv(true, true);
#
#     var dfp_home_b = googletag.sizeMapping()
#         .addSize([992,0], [[970, 90], [970,250]])
#         .addSize([768,0], [728,90])
#         .addSize([0, 0], [[320, 50], [300, 250]]).build();
#
#     googletag.defineSlot(slotName, [[970, 90], [970,250], [728, 90], [320, 50], [300, 250]], 'dfp-home-b')
#         .defineSizeMapping(dfp_home_b)
#         .addService(googletag.pubads())
#         .setTargeting('pos', 'home-b')
#         .setCollapseEmptyDiv(true, true);
#
#     var dfp_home_c = googletag.sizeMapping()
#         .addSize([992,0], [[970, 90], [970,250]])
#         .addSize([768,0], [728,90])
#         .addSize([0, 0], [[320, 50], [300, 250]]).build();
#
#     googletag.defineSlot(slotName, [[970, 90], [970,250], [728, 90], [320, 50], [300, 250]], 'dfp-home-c')
#         .defineSizeMapping(dfp_home_c)
#         .addService(googletag.pubads())
#         .setTargeting('pos', 'home-c')
#         .setCollapseEmptyDiv(true, true);
#
#     var dfp_home_d = googletag.sizeMapping()
#         .addSize([1200, 0], [728, 90])
#         .addSize([992,0], [320, 50])
#         .addSize([768,0], [728,90])
#         .addSize([0, 0], [320, 50]).build();
#
#     googletag.defineSlot(slotName, [[728, 90], [320, 50], [728, 90], [320, 50]], 'dfp-home-d')
#         .defineSizeMapping(dfp_home_d)
#         .addService(googletag.pubads())
#         .setTargeting('pos', 'home-d')
#         .setCollapseEmptyDiv(true, true);
#
#     var dfp_home_e = googletag.sizeMapping()
#         .addSize([992,0], [970, 90])
#         .addSize([768,0], [728,90])
#         .addSize([0, 0], [320, 50]).build();
#
#     googletag.defineSlot(slotName, [[970, 90], [728, 90], [320, 50]], 'dfp-home-e')
#         .defineSizeMapping(dfp_home_e)
#         .addService(googletag.pubads())
#         .setTargeting('pos', 'home-e')
#         .setCollapseEmptyDiv(true, true);
#
#
#                     s_values.forEach(function (s_value, index) {
#                         s_key = 's' + (index + 1);
#                         googletag.pubads().setTargeting(s_key, s_value);
#                     });
#
#
#     googletag.defineSlot(slotName, [160,60], 'dfp-header-left')
#         .addService(googletag.pubads())
#         .setTargeting('pos', 'header-left');
#
#
#
#     googletag.defineSlot(slotName, [160,60], 'dfp-header-right')
#         .addService(googletag.pubads())
#         .setTargeting('pos', 'header-right');
#
#
#
#
#                     googletag.pubads().setTargeting('type', type);
#                     googletag.pubads().setTargeting('breakpoint', breakpoint);
#                     googletag.pubads().setTargeting('dfp_test', dfp_test);
#                     googletag.pubads().collapseEmptyDivs();
#                     googletag.pubads().enableSingleRequest();
#                     googletag.enableServices();
#                 });
#             })();
#         </script>
# <link href="https://static.broadway.com/css/main.b2decb6ed31e.css" rel="stylesheet"/>
# </meta></meta></meta></meta></link></head>
# <body>
# <h1 class="sr-only">Broadway Shows and Tickets</h1>
# <a class="sr-only nav-bar__skiplink" href="#skiplink-target">Skip to main content</a>
# <!-- Google Tag Manager -->
# <noscript>
# <iframe height="0" src="//www.googletagmanager.com/ns.html?id=GTM-HRPQ" style="display:none; visibility:hidden" width="0"></iframe>
# </noscript>
# <script type="text/javascript">
#     googletag.cmd.push(function() { googletag.display('dfp-home-a'); });
# </script>
# <div id="dfp-home-a" style="display:none;">
# </div>
# <!-- Admin Banner -->
# <div class="announcement-hook-js"></div>
# <!-- Navigation Bar -->
# <header class="global-navigation-wrapper">
# <nav aria-expanded="false" class="global-navigation-container global-nav-js mbn white" id="nav-menu" role="navigation">
# <h2 class="sr-only">Navigation</h2>
# <div class="nav-bar__top-wrapper">
# <ul class="nav-bar__top container">
# <li>
# <script type="text/javascript">
#     googletag.cmd.push(function() { googletag.display('dfp-nav-mastercard-desktop'); });
# </script>
# <div id="dfp-nav-mastercard-desktop">
# </div>
# </li>
# <li>
# <a class="nav-bar__top-link" data-qa="bwy-show-header" href="/the-show/" rel="nofollow">
# <svg fill="none" height="12" viewbox="0 0 12 12" width="12" xmlns="http://www.w3.org/2000/svg">
# <path d="M10.9091 1H1.09091C0.490909 1 0 1.5 0 2.11111V8.77778C0 9.38889 0.490909 10 1.09091 10H4V11.5H8V10H10.9091C11.5091 10 11.9945 9.38889 11.9945 8.77778L12 2.11111C12 1.5 11.5091 1 10.9091 1ZM10.5 8.5H1.5V2.5H10.5V8.5Z" fill="currentColor"></path>
# <rect fill="#C5C6CD" height="3" width="6" x="3" y="4"></rect>
# </svg>
#
#                         The Broadway Show
#                     </a>
# </li>
# <li>
# <a class="nav-bar__top-link" data-qa="giftcard-header" href="/gift-certificates/">
# <svg fill="none" height="12" viewbox="0 0 12 12" width="12" xmlns="http://www.w3.org/2000/svg">
# <path clip-rule="evenodd" d="M9.93317 0.54827C9.55529 0.182755 9.09808 0 8.56154 0C7.94423 0 7.45962 0.214842 7.10769 0.644531L6 2.02567L4.89231 0.644531C4.54038 0.214842 4.05577 0 3.43846 0C2.90192 0 2.44471 0.182755 2.06683 0.54827C1.68894 0.913785 1.5 1.35602 1.5 1.875C1.5 2.3019 1.62784 2.67688 1.88354 2.99994L0 3H3.74227C3.53608 3 3.36083 2.92708 3.21649 2.78125C3.07216 2.63542 3 2.45833 3 2.25C3 2.04167 3.07216 1.86458 3.21649 1.71875C3.36083 1.57292 3.53608 1.5 3.74227 1.5C3.96392 1.5 4.14175 1.58073 4.27577 1.74219L5.25 3H6.75L7.71983 1.74219C7.85431 1.58073 8.03276 1.5 8.25517 1.5C8.46207 1.5 8.63793 1.57292 8.78276 1.71875C8.92759 1.86458 9 2.04167 9 2.25C9 2.45833 8.92759 2.63542 8.78276 2.78125C8.63793 2.92708 8.46207 3 8.25517 3H12L10.1165 2.99994C10.3722 2.67688 10.5 2.3019 10.5 1.875C10.5 1.35602 10.3111 0.913785 9.93317 0.54827ZM12 4H0V6H1H11H12V4ZM11 12V7.5H1V12H11Z" fill="currentColor" fill-rule="evenodd"></path>
# </svg>
#
#                         Gift Cards
#                     </a>
# </li>
# <li>
# <a class="nav-bar__top-link" data-qa="groups-header" href="https://groups.broadway.com">
# <svg fill="none" height="12" viewbox="0 0 12 12" width="12" xmlns="http://www.w3.org/2000/svg">
# <path clip-rule="evenodd" d="M3.5 2C4.32843 2 5 1.10457 5 0H7V12H5C5 10.8954 4.32843 10 3.5 10C2.67157 10 2 10.8954 2 12H0V0H2C2 1.10457 2.67157 2 3.5 2ZM12 3L8.5 1V11L12 3Z" fill="currentColor" fill-rule="evenodd"></path>
# </svg>
#
#                         Group Sales
#                     </a>
# </li>
# </ul>
# </div>
# <div class="nav-bar__bottom-wrapper">
# <div class="nav-bar__bottom container">
# <div class="nav-bar__bottom__mobile">
# <a aria-label="Broadway.com Home" class="nav-bar__logo-link" data-qa="header_logo" href="/" style="fill: #fff;">
# <svg aria-label="Home" class="" data-qa="broadway-logo" fill="currentColor" height="32" viewbox="0 0 109 30" width="116" xmlns="http://www.w3.org/2000/svg">
# <g fill-rule="evenodd">
# <path d="M107.972009,1.02532258 L107.128591,1.48451613 C105.326942,2.69129032 103.740871,3.89032258 102.627618,6.00919355 C101.544884,3.97693548 100.083316,2.74064516 98.1009689,1.46080645 L96.8888889,0.870967742 L96.8888889,27.3919355 L99.2999689,28.2629032 L99.2999689,6.08709677 C100.613667,7.84116851 101.301333,9.98417528 101.253249,12.1741935 L101.253249,28.2614516 L104.155556,29.1290323 L104.155556,11.7396774 C104.162139,9.82694913 104.846961,7.97840314 106.088489,6.52209677 L106.088489,29.1290323 L108.526698,30 L108.526698,0.810967742 M79.9648222,1.81790323 C79.46972,2.49096774 79.4392,3.01596774 79.4392,4.34758065 L79.4392,20.8698387 C79.4392,22.2556452 79.5980978,23.4667742 80.2273911,24.2627419 C80.8010011,25.0727685 81.7073572,25.5839873 82.6980578,25.6562903 C83.8200311,25.7966129 84.6116133,25.6679032 85.2559244,25.1525806 C86.0542889,24.5129032 86.2296578,23.336129 86.2296578,21.738871 L86.2296578,14.7832258 L83.7992,14.3477419 L83.7992,21.7393548 C83.7992,22.5735484 83.6703378,22.9277419 83.4659022,23.1082258 C83.2730377,23.2396728 83.0308423,23.2765199 82.8075422,23.2083871 C82.1065511,23.1212903 81.8822533,22.7903226 81.8822533,21.3048387 L81.8822533,4.34806452 C81.8822533,2.77064516 82.1922978,2.83258065 82.7692711,2.83258065 C83.3869378,2.84612903 83.7992,3.15435484 83.7992,4.78306452 L83.7992,11.6196774 L86.2311111,11.5993548 L86.2311111,4.76274194 C86.2311111,3.54387097 86.328,2.73048387 85.9825911,2.11790323 C85.8297147,1.80628317 85.6223464,1.52443881 85.3702533,1.28564516 C84.6468493,0.667542765 83.7220914,0.335044692 82.77024,0.350806452 C81.8033777,0.350038988 80.8840307,0.769516666 80.2516133,1.5 L79.9648222,1.81790323 Z M65.39564,0.496451613 L65.39564,8.69612903 C65.39564,9.8066129 65.3815911,10.4312903 65.73136,11.0472581 C65.8748899,11.3007572 66.054378,11.5321858 66.2642489,11.7343548 C66.7204034,12.1296958 67.2527546,12.4275847 67.82852,12.6096774 L67.82852,23.7024194 L70.2507422,23.9927419 L70.2507422,12.6653226 C70.8529557,12.5253674 71.4166354,12.2538589 71.9012444,11.8703226 L72.1957867,11.546129 C72.6937956,10.9103226 72.6521333,10.0620968 72.6521333,8.69564516 L72.6521333,0.496451613 L70.2299111,0.496451613 L70.2299111,8.69612903 C70.2635377,9.25928249 70.0914001,9.81548846 69.7454667,10.2614516 C69.5527087,10.4055029 69.3066717,10.4585034 69.0716044,10.4066129 C68.3507511,10.3906452 67.8222222,10.1070968 67.8222222,8.69612903 L67.8222222,0.476129032 L65.39564,0.496451613 Z M52.1005467,18.701129 C51.4911156,17.1256452 50.8700578,15.5908065 50.8700578,13.9137097 L50.8700578,0.971129032 L48.4478356,0.971129032 L48.4478356,13.9137097 C48.4675772,15.5696079 48.1767445,17.21456 47.5903689,18.7635484 C46.9132393,17.2337342 46.543869,15.5858661 46.5032756,13.9137097 L46.5032756,0.971129032 L44.0718489,0.971129032 L44.0718489,14.3482258 C43.9986379,15.9213013 44.225679,17.493929 44.7408667,18.9822581 C44.8377556,19.2725806 44.9641956,19.5832258 45.1177644,19.9301613 C45.7233434,21.243148 46.4742285,22.4842692 47.3563822,23.6303226 L47.60684,23.9690323 L47.8408267,23.6196774 C48.649237,22.4498664 49.3190195,21.1903148 49.8367378,19.8662903 C50.3865201,21.1483562 51.0606936,22.3735591 51.8496044,23.5243548 L52.0806844,23.8630645 L52.3301733,23.5359677 C53.278072,22.2907362 54.0514343,20.9221461 54.6288622,19.4680645 L54.8483156,18.8903226 C55.4073644,17.3322581 55.2203689,15.6624194 55.2203689,13.9132258 L55.2203689,0.951290323 L52.7981467,0.951290323 L52.7981467,13.9137097 C52.8707442,15.539173 52.6344948,17.1638667 52.1005467,18.701129 Z M21.9453333,0.318387097 C21.0659269,0.343481633 20.2292374,0.702750877 19.6059511,1.32290323 C19.4122259,1.49390378 19.236878,1.68461211 19.0827511,1.89193548 C18.5857111,2.64241935 18.4045289,3.44032258 18.4045289,4.8483871 L18.4045289,22.2135484 C18.4045289,23.4745161 18.5537378,24.2753226 18.9030222,24.8917742 C18.999352,25.1971675 19.16327,25.4769865 19.3826222,25.7104839 C20.1488792,26.236344 21.1005504,26.4177845 22.0068578,26.2108065 C22.9384444,26.0322581 2 ...
# <g transform="translate(71.698 20.806)">
# <ellipse cx="3.149" cy="3.145" fill="#B62825" rx="3.149" ry="3.145"></ellipse>
# <path d="M6.27817299,3.49809825 L4.5624831,3.49809825 L4.36938039,0.967741935 L3.19475078,3.49953053 L0.968888889,3.49953053 L2.47085113,4.58042236 L1.74559557,5.96151068 C1.91061051,6.0436964 2.0838641,6.11183961 2.26378762,6.16437348 L3.40433786,5.42833045 L4.17310964,6.12020429 C4.39200134,6.0450404 4.59998719,5.94645479 4.79406698,5.82744402 L4.67740276,4.59617741 L6.2326075,3.7848309 C6.25207398,3.6907223 6.26733093,3.59507639 6.27817299,3.49809825 Z" fill="#FFF"></path>
# </g>
# </g>
# </svg>
# </a>
# <button aria-controls="nav-menu" aria-haspopup="menu/dialog" aria-label="Menu" aria-pressed="false" class="nav-bar__menu-button aria-nav-controls-js nav-bar__menu-button--open" data-qa="header_hamburger_menu">
# <svg height="12px" version="1.1" viewbox="0 0 16 12" width="16px" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
# <title>Icon/Menu</title>
# <g fill="none" fill-rule="evenodd" stroke="none" stroke-width="1">
# <g fill="currentColor" transform="translate(-652.000000, -216.000000)">
# <g transform="translate(528.000000, 214.000000)">
# <g id="Icon/Menu" transform="translate(124.000000, 0.000000)">
# <path d="M16,12 L16,14 L0,14 L0,12 L16,12 Z M16,7 L16,9 L0,9 L0,7 L16,7 Z M16,2 L16,4 L0,4 L0,2 L16,2 Z" id="Menu"></path>
# </g>
# </g>
# </g>
# </g>
# </svg>
# <span style="margin-top: 3px">Menu</span>
# </button>
# <button aria-controls="nav-menu" aria-haspopup="menu/dialog" aria-label="Close Menu" aria-pressed="false" class="nav-bar__menu-button aria-nav-controls-js nav-bar__menu-button--close" data-qa="header_hamburger_menu_close">
# <svg class="" height="16" version="1.1" viewbox="0 0 16 16" width="16" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
# <title>Icon/Close</title>
# <g fill="none" fill-rule="evenodd" id="General" stroke="none" stroke-width="1">
# <g fill="currentColor" id="Branding,-Symbols-&amp;-Icons" transform="translate(-559.000000, -214.000000)">
# <g id="UI-Icons" transform="translate(528.000000, 214.000000)">
# <g id="Icon/Close" transform="translate(31.000000, 0.000000)">
# <polygon id="Close" points="16 1.61142857 14.3885714 0 8 6.38857143 1.61142857 0 0 1.61142857 6.38857143 8 0 14.3885714 1.61142857 16 8 9.61142857 14.3885714 16 16 14.3885714 9.61142857 8"></polygon>
# </g>
# </g>
# </g>
# </g>
# </svg>
# </button>
# </div>
# <div class="nav-bar__bottom-header">
# <ul class="nav-bar__bottom__body">
# <li>
# <a class="nav-bar__bottom-link" data-qa="shows-header" href="/shows/tickets/">
#                                 Shows
#                             </a>
# </li>
# <li>
# <a class="nav-bar__bottom-link" data-qa="tbd-header" href="/shows/find-by-date/">
#                                 Tickets
#                             </a>
# </li>
# <li>
# <a class="nav-bar__bottom-link" data-qa="buzz-header" href="/buzz/">
#                                 News &amp; Features
#                             </a>
# </li>
# </ul>
# </div>
# <div id="navsearch--app"></div>
# </div>
# </div>
# <div class="nav-bar-flyout-menu-container" role="menu">
# <ul class="nav-flyout-menu-top">
# <li>
# <a class="nav-flyout-menu-link" data-qa="header_home" href="/" role="menuitem">
#                         Home
#                     </a>
# </li>
# <li>
# <a class="nav-flyout-menu-link" data-qa="header_shows" href="/shows/tickets/" role="menuitem">
#                         Shows
#                     </a>
# </li>
# <li>
# <a class="nav-flyout-menu-link" data-qa="tbd-header" href="/shows/find-by-date/">
#                         Tickets
#                     </a>
# </li>
# <li>
# <a class="nav-flyout-menu-link" data-qa="header_buzz" href="/buzz/" role="menuitem">
#                         News &amp; Features
#                     </a>
# </li>
# </ul>
# <div class="container">
# <div class="nav-flyout-menu-divider"></div>
# </div>
# <ul class="nav-flyout-menu-bottom">
# <li>
# <a class="nav-flyout-menu-link" href="/the-show/" rel="nofollow">
#                         The Broadway Show
#                     </a>
# </li>
# <li>
# <a class="nav-flyout-menu-link" href="/gift-certificates/">
#                         Gift Cards
#                     </a>
# </li>
# <li>
# <a class="nav-flyout-menu-link" data-qa="Newsletters_button" href="https://announcements.broadway.com/preference-center">
#                         Newsletters
#                     </a>
# </li>
# <li>
# <a class="nav-flyout-menu-link" href="https://groups.broadway.com">
#                         Group Sales
#                     </a>
# </li>
# <li>
# <a class="nav-flyout-menu-link" data-qa="Contact_link" href="/contact-us/">
#                         Info &amp; Support
#                     </a>
# </li>
# </ul>
# <div class="container">
# <div class="nav-flyout-menu-divider"></div>
# </div>
# <div class="nav-flyout-mastercard-promotion">
# <script type="text/javascript">
#     googletag.cmd.push(function() { googletag.display('dfp-nav-mastercard-mobile'); });
# </script>
# <div id="dfp-nav-mastercard-mobile">
# </div>
# </div>
# </div>
# </nav>
# </header>
# <div class="visually-hidden" id="skiplink-target" tabindex="-1"></div>
# <div class="homepage__background--dark">
# <div class="homepage__main-logo__container container">
# <div class="homepage__main-logo__ad-left">
# <script type="text/javascript">
#     googletag.cmd.push(function() { googletag.display('dfp-header-left'); });
# </script>
# <div id="dfp-header-left">
# </div>
# </div>
# <div class="homepage__main-logo">
# <a href="/">
# <img alt="Broadway.com" height="62" src="https://static.broadway.com/img/logos/bwy-com-trans_logo-224x62.32cc971e47a2.png" srcset="https://static.broadway.com/img/logos/bwy-com-trans_logo-224x62.32cc971e47a2.png 1x,
#                                 https://static.broadway.com/img/logos/bwy-com-trans_logo-448x124.f23c3b57a30a.png 2x" width="224"/>
# </a>
# </div>
# <div class="homepage__main-logo__ad-right">
# <script type="text/javascript">
#     googletag.cmd.push(function() { googletag.display('dfp-header-right'); });
# </script>
# <div id="dfp-header-right">
# </div>
# </div>
# </div>
# <!-- Tickets By Date -->
# <div id="tickets-by-date--modal"></div>
# <section class="homepage__tickets-by-date">
# <div id="tickets-by-date--form"></div>
# </section>
# <div class="homepage__ad-container">
# <script type="text/javascript">
#     googletag.cmd.push(function() { googletag.display('dfp-home-b'); });
# </script>
# <div id="dfp-home-b" style="display:none;">
# </div>
# </div>
# <!-- Gallery -->
# <div class="gallery__tabs-background">
# <div class="gallery__heading-container container">
# <div class="gallery__tabs-container" role="tablist">
# <button aria-selected="true" class="gallery__tab active-tab" data-tabindex="1" role="tab" tabindex="0">
# <h2 class="gallery__heading">Broadway</h2>
# <div class="gallery__tab-slider"></div>
# </button>
# <button aria-selected="false" class="gallery__tab" data-tabindex="2" role="tab" tabindex="-1">
# <h2 class="gallery__heading">Off-Broadway</h2>
# </button>
# </div>
# <div class="gallery__tabs-mask"></div>
# <a class="gallery__view-shows-button" href="/shows/tickets/">
#             View All Shows
#             <svg class="" fill="currentColor" height="14" style="margin-left: 6px;" viewbox="0 0 8 14" width="8" xmlns="http://www.w3.org/2000/svg">
# <path clip-rule="evenodd" d="M0 1L0.96482 0L8 7L0.96482 14L0 13L6 7L0 1Z" fill="currentColor" fill-rule="evenodd"></path>
# </svg>
# </a>
# </div>
# </div>
# <div class="gallery__background">
# <div aria-hidden="false" class="gallery__tab-content container" data-tabindex="1" role="tabpanel" tabindex="0">
# <a class="gallery__card" href="/shows/hadestown/">
# <img alt="Live performance of Hadestown" class="gallery__card-image lazyload" data-src="https://imaging.broadway.com/images/regular-43/w300/107869-6.jpg" height="160" src="https://static.broadway.com/img/placeholders/shows/poster-placeholder.863b7db440fb.png" width="215"/>
# <div class="gallery__card-body">
# <div class="gallery__card-title">
#                                 Hadestown
#                             </div>
# </div>
# </a>
# <a class="gallery__card" href="/shows/book-mormon/">
# <img alt="Live performance of The Book of Mormon" class="gallery__card-image lazyload" data-src="https://imaging.broadway.com/images/regular-43/w300/114880-9.jpg" height="160" src="https://static.broadway.com/img/placeholders/shows/poster-placeholder.863b7db440fb.png" width="215"/>
# <div class="gallery__card-body">
# <div class="gallery__card-title">
#                                 The Book of Mormon
#                             </div>
# </div>
# </a>
# <a class="gallery__card" href="/shows/mrs-doubtfire/">
# <img alt="Live performance of Mrs. Doubtfire" class="gallery__card-image lazyload" data-src="https://imaging.broadway.com/images/regular-43/w300/119840-0.jpg" height="160" src="https://static.broadway.com/img/placeholders/shows/poster-placeholder.863b7db440fb.png" width="215"/>
# <div class="gallery__card-body">
# <div class="gallery__card-title">
#                                 Mrs. Doubtfire
#                             </div>
# </div>
# </a>
# <a class="gallery__card" href="/shows/aladdin-broadway/">
# <img alt="Live performance of Aladdin" class="gallery__card-image lazyload" data-src="https://imaging.broadway.com/images/regular-43/w300/93415-2.jpg" height="160" src="https://static.broadway.com/img/placeholders/shows/poster-placeholder.863b7db440fb.png" width="215"/>
# <div class="gallery__card-body">
# <div class="gallery__card-title">
#                                 Aladdin
#                             </div>
# </div>
# </a>
# <a class="gallery__card" href="/shows/aint-too-proud/">
# <img alt="Live performance of Ain't Too Proud – The Life and Times of The Temptations" class="gallery__card-image lazyload" data-src="https://imaging.broadway.com/images/regular-43/w300/120395-2.png" height="160" src="https://static.broadway.com/img/placeholders/shows/poster-placeholder.863b7db440fb.png" width="215"/>
# <div class="gallery__card-body">
# <div class="gallery__card-title">
#                                 Ain't Too Proud
#                             </div>
# </div>
# </a>
# <a class="gallery__card" href="/shows/hamilton-broadway/">
# <img alt="Live performance of Hamilton" class="gallery__card-image lazyload" data-src="https://imaging.broadway.com/images/regular-43/w300/106237-5.jpg" height="160" src="https://static.broadway.com/img/placeholders/shows/poster-placeholder.863b7db440fb.png" width="215"/>
# <div class="gallery__card-body">
# <div class="gallery__card-title">
#                                 Hamilton
#                             </div>
# </div>
# </a>
# <a class="gallery__card" href="/shows/waitress/">
# <img alt="Live performance of Waitress" class="gallery__card-image lazyload" data-src="https://imaging.broadway.com/images/regular-43/w300/120053-25.jpeg" height="160" src="https://static.broadway.com/img/placeholders/shows/poster-placeholder.863b7db440fb.png" width="215"/>
# <div class="gallery__card-body">
# <div class="gallery__card-title">
#                                 Waitress
#                             </div>
# </div>
# </a>
# <a class="gallery__card" href="/shows/moulin-rouge-musical/">
# <img alt="Live performance of Moulin Rouge! The Musical" class="gallery__card-image lazyload" data-src="https://imaging.broadway.com/images/regular-43/w300/110979-4.jpg" height="160" src="https://static.broadway.com/img/placeholders/shows/poster-placeholder.863b7db440fb.png" width="215"/>
# <div class="gallery__card-body">
# <div class="gallery__card-title">
#                                 Moulin Rouge! The Musical
#                             </div>
# </div>
# </a>
# <a class="gallery__card" href="/shows/wicked/">
# <img alt="Live performance of Wicked" class="gallery__card-image lazyload" data-src="https://imaging.broadway.com/images/regular-43/w300/117700-3.jpg" height="160" src="https://static.broadway.com/img/placeholders/shows/poster-placeholder.863b7db440fb.png" width="215"/>
# <div class="gallery__card-body">
# <div class="gallery__card-title">
#                                 Wicked
#                             </div>
# </div>
# </a>
# <a class="gallery__card" href="/shows/come-away/">
# <img alt="Live performance of Come From Away" class="gallery__card-image lazyload" data-src="https://imaging.broadway.com/images/regular-43/w300/87786-6.jpg" height="160" src="https://static.broadway.com/img/placeholders/shows/poster-placeholder.863b7db440fb.png" width="215"/>
# <div class="gallery__card-body">
# <div class="gallery__card-title">
#                                 Come From Away
#                             </div>
# </div>
# </a>
# <a class="gallery__card" href="/shows/to-kill-mockingbird/">
# <img alt="Live performance of To Kill a Mockingbird" class="gallery__card-image lazyload" data-src="https://imaging.broadway.com/images/regular-43/w300/120394-0.jpg" height="160" src="https://static.broadway.com/img/placeholders/shows/poster-placeholder.863b7db440fb.png" width="215"/>
# <div class="gallery__card-body">
# <div class="gallery__card-title">
#                                 To Kill a Mockingbird
#                             </div>
# </div>
# </a>
# <a class="gallery__card" href="/shows/the-phantom-of-the-opera/">
# <img alt="Live performance of The Phantom of the Opera" class="gallery__card-image lazyload" data-src="https://imaging.broadway.com/images/regular-43/w300/85096-4.jpg" height="160" src="https://static.broadway.com/img/placeholders/shows/poster-placeholder.863b7db440fb.png" width="215"/>
# <div class="gallery__card-body">
# <div class="gallery__card-title">
#                                 The Phantom of the Opera
#                             </div>
# </div>
# </a>
# <a class="gallery__card" href="/shows/tina-tina-turner-musical/">
# <img alt="Live performance of Tina: The Tina Turner Musical" class="gallery__card-image lazyload" data-src="https://imaging.broadway.com/images/regular-43/w300/111684-5.png" height="160" src="https://static.broadway.com/img/placeholders/shows/poster-placeholder.863b7db440fb.png" width="215"/>
# <div class="gallery__card-body">
# <div class="gallery__card-title">
#                                 Tina: The Tina Turner Musical
#                             </div>
# </div>
# </a>
# <a class="gallery__card" href="/shows/mj/">
# <img alt="Live performance of MJ The Musical" class="gallery__card-image lazyload" data-src="https://imaging.broadway.com/images/regular-43/w300/120056-2.jpg" height="160" src="https://static.broadway.com/img/placeholders/shows/poster-placeholder.863b7db440fb.png" width="215"/>
# <div class="gallery__card-body">
# <div class="gallery__card-title">
#                                 MJ The Musical
#                             </div>
# </div>
# </a>
# <a class="gallery__card" href="/shows/chicago/">
# <img alt="Live performance of Chicago" class="gallery__card-image lazyload" data-src="https://imaging.broadway.com/images/regular-43/w300/87147-6.jpg" height="160" src="https://static.broadway.com/img/placeholders/shows/poster-placeholder.863b7db440fb.png" width="215"/>
# <div class="gallery__card-body">
# <div class="gallery__card-title">
#                                 Chicago
#                             </div>
# </div>
# </a>
# <a class="gallery__card" href="/shows/company/">
# <img alt="Live performance of Company" class="gallery__card-image lazyload" data-src="https://imaging.broadway.com/images/regular-43/w300/116373-3.jpg" height="160" src="https://static.broadway.com/img/placeholders/shows/poster-placeholder.863b7db440fb.png" width="215"/>
# <div class="gallery__card-body">
# <div class="gallery__card-title">
#                                 Company
#                             </div>
# </div>
# </a>
# <a class="gallery__card" href="/shows/dear-evan-hansen/">
# <img alt="Live performance of Dear Evan Hansen" class="gallery__card-image lazyload" data-src="https://imaging.broadway.com/images/regular-43/w300/116200-3.jpg" height="160" src="https://static.broadway.com/img/placeholders/shows/poster-placeholder.863b7db440fb.png" width="215"/>
# <div class="gallery__card-body">
# <div class="gallery__card-title">
#                                 Dear Evan Hansen
#                             </div>
# </div>
# </a>
# <a class="gallery__card" href="/shows/the-lion-king/">
# <img alt="Live performance of The Lion King" class="gallery__card-image lazyload" data-src="https://imaging.broadway.com/images/regular-43/w300/112487-6.jpg" height="160" src="https://static.broadway.com/img/placeholders/shows/poster-placeholder.863b7db440fb.png" width="215"/>
# <div class="gallery__card-body">
# <div class="gallery__card-title">
#                                 The Lion King
#                             </div>
# </div>
# </a>
# <a class="gallery__card" href="/shows/jagged-little-pill/">
# <img alt="Live performance of Jagged Little Pill" class="gallery__card-image lazyload" data-src="https://imaging.broadway.com/images/regular-43/w300/117205-4.jpg" height="160" src="https://static.broadway.com/img/placeholders/shows/poster-placeholder.863b7db440fb.png" width="215"/>
# <div class="gallery__card-body">
# <div class="gallery__card-title">
#                                 Jagged Little Pill
#                             </div>
# </div>
# </a>
# <a class="gallery__card" href="/shows/harry-potter-and-cursed-child-broadway/">
# <img alt="Live performance of Harry Potter and the Cursed Child" class="gallery__card-image lazyload" data-src="https://imaging.broadway.com/images/regular-43/w300/111885-6.jpg" height="160" src="https://static.broadway.com/img/placeholders/shows/poster-placeholder.863b7db440fb.png" width="215"/>
# <div class="gallery__card-body">
# <div class="gallery__card-title">
#                                 Harry Potter and the Cursed Child
#                             </div>
# </div>
# </a>
# <a class="gallery__card" href="/shows/david-byrnes-american-utopia/">
# <img alt="Live performance of David Byrne's American Utopia" class="gallery__card-image lazyload" data-src="https://imaging.broadway.com/images/regular-43/w300/112999-30.jpg" height="160" src="https://static.broadway.com/img/placeholders/shows/poster-placeholder.863b7db440fb.png" width="215"/>
# <div class="gallery__card-body">
# <div class="gallery__card-title">
#                                 David Byrne's American Utopia
#                             </div>
# </div>
# </a>
# <a class="gallery__card" href="/shows/girl-north-from-the-country/">
# <img alt="Live performance of Girl From the North Country" class="gallery__card-image lazyload" data-src="https://imaging.broadway.com/images/regular-43/w300/116761-6.jpg" height="160" src="https://static.broadway.com/img/placeholders/shows/poster-placeholder.863b7db440fb.png" width="215"/>
# <div class="gallery__card-body">
# <div class="gallery__card-title">
#                                 Girl From the North Country
#                             </div>
# </div>
# </a>
# <a class="gallery__card" href="/shows/diana/">
# <img alt="Live performance of Diana" class="gallery__card-image lazyload" data-src="https://imaging.broadway.com/images/regular-43/w300/117274-3.jpg" height="160" src="https://static.broadway.com/img/placeholders/shows/poster-placeholder.863b7db440fb.png" width="215"/>
# <div class="gallery__card-body">
# <div class="gallery__card-title">
#                                 Diana
#                             </div>
# </div>
# </a>
# <a aria-label="View All Broadway" class="gallery__view-shows-card" href="https://www.broadway.com/shows/tickets/?category=broadway">
# <svg class="" fill="#C5C6CD" height="35" style="" viewbox="0 0 8 14" width="20" xmlns="http://www.w3.org/2000/svg">
# <path clip-rule="evenodd" d="M0 1L0.96482 0L8 7L0.96482 14L0 13L6 7L0 1Z" fill="#C5C6CD" fill-rule="evenodd"></path>
# </svg>
# </a>
# <div class="gallery__content-mask">
# <button class="gallery__expand-button bwy-button-primary">View More</button>
# </div>
# <a class="gallery__expanded-button bwy-button-primary hidden" href="https://www.broadway.com/shows/tickets/?category=broadway">
#                         Explore All Shows
#                     </a>
# <div class="gallery__card-mask"></div>
# </div>
# <div aria-hidden="true" class="gallery__tab-content container hidden" data-tabindex="2" role="tabpanel" tabindex="0">
# <a class="gallery__card" href="/shows/blue-man-group/">
# <img alt="Live performance of Blue Man Group" class="gallery__card-image lazyload" data-src="https://imaging.broadway.com/images/regular-43/w300/80286-2.jpg" height="160" src="https://static.broadway.com/img/placeholders/shows/poster-placeholder.863b7db440fb.png" width="215"/>
# <div class="gallery__card-body">
# <div class="gallery__card-title">
#                                 Blue Man Group
#                             </div>
# </div>
# </a>
# <a class="gallery__card" href="/shows/stomp/">
# <img alt="Live performance of Stomp" class="gallery__card-image lazyload" data-src="https://imaging.broadway.com/images/regular-43/w300/96226-4.jpg" height="160" src="https://static.broadway.com/img/placeholders/shows/poster-placeholder.863b7db440fb.png" width="215"/>
# <div class="gallery__card-body">
# <div class="gallery__card-title">
#                                 Stomp
#                             </div>
# </div>
# </a>
# <a class="gallery__card" href="/shows/jersey-boys/">
# <img alt="Live performance of Jersey Boys" class="gallery__card-image lazyload" data-src="https://imaging.broadway.com/images/regular-43/w300/115763-5.jpg" height="160" src="https://static.broadway.com/img/placeholders/shows/poster-placeholder.863b7db440fb.png" width="215"/>
# <div class="gallery__card-body">
# <div class="gallery__card-title">
#                                 Jersey Boys
#                             </div>
# </div>
# </a>
# <a class="gallery__card" href="/shows/little-shop-horrors/">
# <img alt="Live performance of Little Shop of Horrors" class="gallery__card-image lazyload" data-src="https://imaging.broadway.com/images/regular-43/w300/113069-19.jpg" height="160" src="https://static.broadway.com/img/placeholders/shows/poster-placeholder.863b7db440fb.png" width="215"/>
# <div class="gallery__card-body">
# <div class="gallery__card-title">
#                                 Little Shop of Horrors
#                             </div>
# </div>
# </a>
# <a aria-label="View All Off-Broadway" class="gallery__view-shows-card" href="https://www.broadway.com/shows/tickets/?category=off-broadway">
# <svg class="" fill="#C5C6CD" height="35" style="" viewbox="0 0 8 14" width="20" xmlns="http://www.w3.org/2000/svg">
# <path clip-rule="evenodd" d="M0 1L0.96482 0L8 7L0.96482 14L0 13L6 7L0 1Z" fill="#C5C6CD" fill-rule="evenodd"></path>
# </svg>
# </a>
# <a class="gallery__explore-button bwy-button-primary" href="https://www.broadway.com/shows/tickets/?category=off-broadway">
#                         Explore All Shows
#                     </a>
# <div class="gallery__card-mask"></div>
# </div>
# </div>
# </div>
# <div class="homepage__ad-container">
# <script type="text/javascript">
#     googletag.cmd.push(function() { googletag.display('dfp-home-c'); });
# </script>
# <div id="dfp-home-c" style="display: none">
# </div>
# </div>
# <div class="homepage__background--light">
# <div class="homepage__container container">
# <!-- Popular Show list -->
# <section class="homepage__popular-shows">
# <h1 class="homepage__heading">
# <a class="homepage__heading-link" href="/shows/tickets/">Popular Broadway Shows</a>
# </h1>
# <div class="popular-shows__list-items">
# <script type="application/ld+json">
# ...
# </ul>
# </section>
# </div>
# </div>
# <div class="footer__column-container">
# <div class="footer__column">
# <section>
# <h1 class="footer__heading">Info &amp; Support</h1>
# <ul class="footer__list">
# <li class="footer__link"><a class="link-grey-100" href="/about-us/">About Us</a></li>
# <li class="footer__link"><a class="link-grey-100" href="/contact-us/">Contact Us</a></li>
# <li class="footer__link"><a class="link-grey-100" href="/faq/">FAQ</a></li>
# <li class="footer__link"><a class="link-grey-100" href="https://www.johngore.com/employment/" rel="noopener noreferrer" target="_blank">Careers</a></li>
# <li class="footer__link"><a class="link-grey-100" href="/accessibility/">Accessibility</a></li>
# </ul>
# </section>
# </div>
# <div class="footer__column">
# <section>
# <h1 class="footer__heading">Follow Us</h1>
# <ul class="footer__list">
# <li class="footer__link"><a class="link-grey-100" href="https://announcements.broadway.com/preference-center">Newsletters</a></li>
# <li class="footer__link"><a class="link-grey-100" href="https://www.facebook.com/Broadway">Facebook</a></li>
# <li class="footer__link"><a class="link-grey-100" href="https://twitter.com/Broadwaycom">Twitter</a></li>
# <li class="footer__link"><a class="link-grey-100" href="https://www.youtube.com/user/Broadwaycom">YouTube</a></li>
# <li class="footer__link"><a class="link-grey-100" href="https://www.instagram.com/broadwaycom/">Instagram</a></li>
# </ul>
# </section>
# </div>
# </div>
# </div>
# <div class="footer__divider"></div>
# <div>
# <ul class="footer__terms-container">
# <li class="footer__term"><a class="link-grey-300" href="/privacy-policy/">Privacy Policy</a></li>
# <li class="footer__term"><a class="link-grey-300" href="/terms/">Website Terms &amp; Conditions</a></li>
# <li class="footer__term"><a class="link-grey-300" href="/purchase-terms/">Purchase Terms &amp; Conditions</a></li>
# <li class="footer__term"><a class="link-grey-300" href="/groups-purchase-terms/">Groups Purchase Terms</a></li>
# <li class="footer__term"><a class="link-grey-300" href="/about-us/ticket-resell-license/">Ticketing License</a></li>
# </ul>
# <div class="footer__copyright">© 2021 Broadway.com</div>
# </div>
# </div>
# </footer>
# <script src="https://static.broadway.com/js/compiled/base.6d8b6785624e.js"></script>
# <!-- Facebook Pixel Code -->
# <noscript>
# <img height="1" src="https://www.facebook.com/tr?id=682878898465597&amp;ev=PageView&amp;noscript=1" style="display:none" width="1"/>
# </noscript>
# <script>
#         window.ENABLE_CUSTOM_START_DATE = 'True';
#         window.CUSTOM_START_DATE = 'Oct. 15, 2021';
#     </script>
# <script src="https://static.broadway.com/js/compiled/homepage.18bd4706175c.js"></script>
# <script>
#         // Gallery Pixel Tracking
#
#             (function($) {
#                 // Generate list of pixels for shows in the gallery
#                 const galleryPixels = [];
#
#
#
#                     galleryPixels[0] = [
#
#                             {
#                                 name: 'Mrs. Doubtfire',
#                                 url: 'https://ad.doubleclick.net/ddm/trackimp/N30602.1277BROADWAY.COM/B25769693.315282297\u003Bdc_trk_aid\u003D507955920\u003Bdc_trk_cid\u003D158423696\u003Bord\u003D[timestamp]\u003Bdc_lat\u003D\u003Bdc_rdid\u003D\u003Btag_for_child_directed_treatment\u003D\u003Btfua\u003D\u003Bg',
#                             },
#
#                             {
#                                 name: 'Aladdin',
#                                 url: 'https://ad.doubleclick.net/ddm/trackimp/N208801.1277BROADWAY.COM/B26396313.311702345\u003Bdc_trk_aid\u003D504611236\u003Bdc_trk_cid\u003D156566037\u003Bord\u003D[timestamp]\u003Bdc_lat\u003D\u003Bdc_rdid\u003D\u003Btag_for_child_directed_treatment\u003D\u003Btfua\u003D\u003B',
#                             },
#
#                             {
#                                 name: 'Ain\u0027t Too Proud – The Life and Times of The Temptations',
#                                 url: 'https://ad.doubleclick.net/ddm/trackimp/N208801.1277BROADWAY.COM/B26145478.314239828\u003Bdc_trk_aid\u003D506932660\u003Bdc_trk_cid\u003D158007942\u003Bord\u003D[timestamp]\u003Bdc_lat\u003D\u003Bdc_rdid\u003D\u003Btag_for_child_directed_treatment\u003D\u003Btfua\u003D\u003B',
#                             },
#
#                             {
#                                 name: 'Waitress',
#                                 url: 'https://ad.doubleclick.net/ddm/trackimp/N30602.1277BROADWAY.COM/B26149135.310711357\u003Bdc_trk_aid\u003D503231300\u003Bdc_trk_cid\u003D155683804\u003Bord\u003D[timestamp]\u003Bdc_lat\u003D\u003Bdc_rdid\u003D\u003Btag_for_child_directed_treatment\u003D\u003Btfua\u003D\u003Bg',
#                             },
#
#                             {
#                                 name: 'Moulin Rouge! The Musical',
#                                 url: 'https://ad.doubleclick.net/ddm/trackimp/N30602.1277BROADWAY.COM/B26168354.313509875\u003Bdc_trk_aid\u003D506017667\u003Bdc_trk_cid\u003D157703241\u003Bord\u003D[timestamp]\u003Bdc_lat\u003D\u003Bdc_rdid\u003D\u003Btag_for_child_directed_treatment\u003D\u003Btfua\u003D\u003Bg',
#                             },
#
#                             {
#                                 name: 'Wicked',
#                                 url: 'https://ad.doubleclick.net/ddm/ad/N4253.1277BROADWAY.COM/B26341813.312248311\u003Bsz\u003D1x1\u003Bord\u003D[timestamp]\u003Bdc_lat\u003D\u003Bdc_rdid\u003D\u003Btag_for_child_directed_treatment\u003D\u003Btfua\u003D',
#                             },
#
#                             {
#                                 name: 'Come From Away',
#                                 url: 'https://ad.doubleclick.net/ddm/trackimp/N510001.1277BROADWAY.COM/B26333498.311824721\u003Bdc_trk_aid\u003D504678420\u003Bdc_trk_cid\u003D156443083\u003Bord\u003D[timestamp]\u003Bdc_lat\u003D\u003Bdc_rdid\u003D\u003Btag_for_child_directed_treatment\u003D\u003Btfua\u003D\u003B',
#                             },
#
#                             {
#                                 name: 'To Kill a Mockingbird',
#                                 url: 'https://ad.doubleclick.net/ddm/trackimp/N30602.1277BROADWAY.COM/B25850477.314388628\u003Bdc_trk_aid\u003D506682278\u003Bdc_trk_cid\u003D157918897\u003Bord\u003D[timestamp]\u003Bdc_lat\u003D\u003Bdc_rdid\u003D\u003Btag_for_child_directed_treatment\u003D\u003Btfua\u003D\u003Bg',
#                             },
#
#                             {
#                                 name: 'Tina: The Tina Turner Musical',
#                                 url: 'https://ad.doubleclick.net/ddm/trackimp/N4253.1277BROADWAY.COM/B26469619.314237636\u003Bdc_trk_aid\u003D507193390\u003Bdc_trk_cid\u003D157399178\u003Bord\u003D[timestamp]\u003Bdc_lat\u003D\u003Bdc_rdid\u003D\u003Btag_for_child_directed_treatment\u003D\u003Btfua\u003D\u003Blt',
#                             },
#
#                             {
#                                 name: 'MJ The Musical',
#                                 url: 'https://ad.doubleclick.net/ddm/ad/N4253.BroadCom/B26589400.316676557\u003Bsz\u003D1x1\u003Bkw\u003D[url_encoded_publisher_data]\u003Bord\u003D[timestamp]\u003Bdc_lat\u003D\u003Bdc_rdid\u003D\u003Btag_for_child_directed_treatment\u003D\u003Btfua\u003D',
#                             },
#
#                             {
#                                 name: 'Chicago',
#                                 url: 'https://ad.doubleclick.net/ddm/trackimp/N30602.1277BROADWAY.COM/B25855650.310471394\u003Bdc_trk_aid\u003D503546632\u003Bdc_trk_cid\u003D155659343\u003Bord\u003D[timestamp]\u003Bdc_lat\u003D\u003Bdc_rdid\u003D\u003Btag_for_child_directed_treatment\u003D\u003Btfua\u003D\u003Bg',
#                             },
#
#                             {
#                                 name: 'The Lion King',
#                                 url: 'https://ad.doubleclick.net/ddm/trackimp/N208801.1277BROADWAY.COM/B26379387.311647515\u003Bdc_trk_aid\u003D504482878\u003Bdc_trk_cid\u003D156254633\u003Bord\u003D[timestamp]\u003Bdc_lat\u003D\u003Bdc_rdid\u003D\u003Btag_for_child_directed_treatment\u003D\u003Btfua\u003D\u003B',
#                             },
#
#                             {
#                                 name: 'Girl From the North Country',
#                                 url: 'https://ad.doubleclick.net/ddm/trackimp/N510001.1277BROADWAY.COM/B25931196.313555224\u003Bdc_trk_aid\u003D506378638\u003Bdc_trk_cid\u003D157521754\u003Bord\u003D[timestamp]\u003Bdc_lat\u003D\u003Bdc_rdid\u003D\u003Btag_for_child_directed_treatment\u003D\u003Btfua\u003D\u003B',
#                             },
#
#                     ];
#
#
#
#                     galleryPixels[1] = [
#
#                     ];
#
#
#                 // Set initial pixels for visible shows
#                 const screenWidth = window.innerWidth;
#                 if (screenWidth > 767) {
#                     const cardCount = getInitialCardCount();
#                     const galleryCards = $('.gallery__card-image').slice(0, cardCount);
#                     addDesktopPixels(galleryPixels[0], galleryCards);
#                 } else {
#                     const galleryCards = $('.gallery__card-image').slice(0, 3);
#                     addMobilePixels(galleryPixels[0], galleryCards);
#                 }
#
#                 // Set initial pixels when switching to a new tab
#                 $('.gallery__tab:not(".active-tab")')
#                     .on('addPixels', function(event, index) {
#                         const pixels = galleryPixels[index];
#                         if (pixels.length) {
#                             const $newTab = $(`.gallery__tab-content[data-tabindex=${(index + 1)}]`);
#                             const galleryCards = $newTab.find('.gallery__card-image');
#                             if (screenWidth > 767) {
#                                 const cardCount = getInitialCardCount();
#                                 addDesktopPixels(pixels, galleryCards.slice(0, cardCount));
#                             } else {
#                                 addMobilePixels(pixels, galleryCards.slice(0, 3));
#                                 scrollDistance = 0;
#                             }
#                         }
#                     });
#
#                 // Set remaining desktop pixels after expanding the gallery
#                 $('.gallery__expand-button')
#                     .one('addPixels', function() {
#                         const $tab = $(this).parents('.gallery__tab-content');
#                         const tabIndex = $tab.attr('data-tabindex') - 1;
#                         const cardCount = getInitialCardCount();
#                         const galleryCards = $tab.find('.gallery__card-image').slice(cardCount);
#                         addDesktopPixels(galleryPixels[tabIndex], galleryCards);
#                     });
#
#                 // Adds pixels when cards scroll into view on mobile
#                 let scrollTimer = null;
#                 let scrollDistance = 0;
#                 $('.gallery__tab-content')
#                     .on('scroll', function (event) {
#                         const $this = $(this);
#                         if (scrollTimer) {
#                             clearTimeout(scrollTimer);
#                         }
#                         scrollTimer = setTimeout(function() {
#                             const scrollValue = $this.scrollLeft();
#                             if (scrollValue > scrollDistance) {
#                                 const tabIndex = $this.attr('data-tabindex') - 1;
#                                 if (galleryPixels[tabIndex].length) {
#                                     const galleryCards = $this.find('.gallery__card-image.lazyloaded');
#                                     addMobilePixels(galleryPixels[tabIndex], galleryCards);
#                                 }
#                                 scrollDistance = scrollValue;
#                             }
#                         }, 250);
#                     });
#
#                 function addDesktopPixels(pixels, cards) {
#                     for (let i = 0; i < cards.length; i++) {
#                         const pixelIndex = getPixelIndex(pixels, cards[i]);
#                         if (pixels[pixelIndex]) {
#                             generatePixel(pixels[pixelIndex].url);
#                             pixels[pixelIndex] = null;
#                         }
#                     }
#                 }
#
#                 // Adds pixels when at least half of a card scrolled into view
#                 function addMobilePixels(pixels, cards) {
#                     for (let i = 0; i < cards.length; i++) {
#                         const pixelIndex = getPixelIndex(pixels, cards[i]);
#                         if (pixels[pixelIndex]) {
#                             const visibleWidth = screenWidth - cards[i].getBoundingClientRect().left;
#                             if (visibleWidth > 107) {
#                                 generatePixel(pixels[pixelIndex].url);
#                                 pixels[pixelIndex] = null;
#                             }
#                         }
#                     }
#                 }
#
#                 // Number of cards initially visible on large viewports
#                 function getInitialCardCount() {
#                     if (screenWidth < 992) {
#                         return 6;
#                     } else if (screenWidth < 1200) {
#                         return 8;
#                     }
#                     return 10;
#                 }
#
#                 // Returns index of show pixel
#                 function getPixelIndex(pixels, element) {
#                     const show = element.getAttribute('alt').split('Live performance of ')[1];
#                     return pixels.findIndex(pixel => pixel && pixel.name === show);
#                 }
#
#                 // Creates an image making a request to the pixel url
#                 function generatePixel(pixel) {
#                     const image = document.createElement('img');
#                     image.setAttribute('style', 'position: absolute; width: 1px; height: 1px;');
#                     const timeStamp = new Date().getTime().toString();
#                     const srcUrl = pixel.replace(/timestamp|cachebuster/gi, timeStamp);
#                     image.src = srcUrl;
#                 }
#             })(jQuery);
#
#
#         // Homepage GA tag manager
#         (function($) {
#             $('div[data-homepage-area-tagging]').on('click', 'a[href]', function(e) {
#                 const $this = $(this);
#                 const targetArea = $(e.delegateTarget).data('homepage-area-tagging');
#                 const targetUrl = $this.prop('href');
#                 dataLayer.push({
#                     'event': 'homepage-area-tag',
#                     'homepage-area': targetArea,
#                     'target-url': targetUrl,
#                 });
#             });
#         })(jQuery);
#     </script>
# <!-- Announcements -->
# <div class="announcement-js announcement-container visually-hidden">
# <div class="announcement">
# <div class="announcement__body">View our complete guide to <a href="/buzz/200777/a-complete-guide-to-broadways-reopening/">Broadway's reopening</a></div>
# </div>
# </div>
# <!-- Navigation, Footer, and Announcements JS -->
# <script>
#             window.BWY = window.BWY || {};
#             jQuery(function($) {
#                 BWY.shared_nav_menu();
#
#
#                     BWY.siteAnnouncement('Wed, 9 Jun 2021 13:09:26 -0400');
#
#             });
#             var campaignID = "";
#             if (campaignID) {
#                 BWY.cookies.setCampaignCookie(campaignID);
#             }
#         </script>
# </body>
# </html>

# %% [markdown]
# After doing some digging in the above text, we found the place on the site we are looking extract the information on. There is a text box on the homepage that lists the popular shows. We will use this to get the urls of each show to extract the information we're looking for.

# %% [markdown]
# For the information below, we will want to use the json library to easily access the dictionary of information we see below.

# %%
#This is how you get to the popular show list. 
scraped.find('div', class_='popular-shows__list-items')
# Out:
# <div class="popular-shows__list-items">
# <script type="application/ld+json">
#         {"@context": "http://schema.org", "@type": "ItemList", "itemListElement": [{"@type": "ListItem", "position": 1, "name": "Moulin Rouge! The Musical", "url": "https://broadway.com/shows/moulin-rouge-musical/"}, {"@type": "ListItem", "position": 2, "name": "Wicked", "url": "https://broadway.com/shows/wicked/"}, {"@type": "ListItem", "position": 3, "name": "The Lion King", "url": "https://broadway.com/shows/the-lion-king/"}, {"@type": "ListItem", "position": 4, "name": "To Kill a Mockingbird", "url": "https://broadway.com/shows/to-kill-mockingbird/"}, {"@type": "ListItem", "position": 5, "name": "Hamilton", "url": "https://broadway.com/shows/hamilton-broadway/"}, {"@type": "ListItem", "position": 6, "name": "Hadestown", "url": "https://broadway.com/shows/hadestown/"}, {"@type": "ListItem", "position": 7, "name": "Chicago", "url": "https://broadway.com/shows/chicago/"}, {"@type": "ListItem", "position": 8, "name": "Waitress", "url": "https://broadway.com/shows/waitress/"}, {"@type": "ListItem", "position": 9, "name": "Tina: The Tina Turner Musical", "url": "https://broadway.com/shows/tina-tina-turner-musical/"}, {"@type": "ListItem", "position": 10, "name": "The Music Man", "url": "https://broadway.com/shows/music-man/"}, {"@type": "ListItem", "position": 11, "name": "David Byrne's American Utopia", "url": "https://broadway.com/shows/david-byrnes-american-utopia/"}, {"@type": "ListItem", "position": 12, "name": "Aladdin", "url": "https://broadway.com/shows/aladdin-broadway/"}, {"@type": "ListItem", "position": 13, "name": "Come From Away", "url": "https://broadway.com/shows/come-away/"}, {"@type": "ListItem", "position": 14, "name": "The Phantom of the Opera", "url": "https://broadway.com/shows/the-phantom-of-the-opera/"}, {"@type": "ListItem", "position": 15, "name": "Harry Potter and the Cursed Child", "url": "https://broadway.com/shows/harry-potter-and-cursed-child-broadway/"}, {"@type": "ListItem", "position": 16, "name": "The Book of Mormon", "url": "https://broadway.com/shows/book-mormon/"}, {"@type": "ListItem", "position": 17, "name": "Ain't Too Proud \u2013 The Life and Times of The Temptations", "url": "https://broadway.com/shows/aint-too-proud/"}, {"@type": "ListItem", "position": 18, "name": "Mrs. Doubtfire", "url": "https://broadway.com/shows/mrs-doubtfire/"}, {"@type": "ListItem", "position": 19, "name": "Jagged Little Pill", "url": "https://broadway.com/shows/jagged-little-pill/"}, {"@type": "ListItem", "position": 20, "name": "Dear Evan Hansen", "url": "https://broadway.com/shows/dear-evan-hansen/"}, {"@type": "ListItem", "position": 21, "name": "Diana", "url": "https://broadway.com/shows/diana/"}, {"@type": "ListItem", "position": 22, "name": "Girl From the North Country", "url": "https://broadway.com/shows/girl-north-from-the-country/"}, {"@type": "ListItem", "position": 23, "name": "MJ The Musical", "url": "https://broadway.com/shows/mj/"}, {"@type": "ListItem", "position": 24, "name": "Company", "url": "https://broadway.com/shows/company/"}]}
#     </script>
# <ol class="hidden display-sm">
# <li class="popular-shows__item">
# <a class="popular-shows__link" href="/shows/moulin-rouge-musical/">
#                     Moulin Rouge! The Musical
#                 </a>
# </li>
# <li class="popular-shows__item">
# <a class="popular-shows__link" href="/shows/wicked/">
#                     Wicked
#                 </a>
# </li>
# <li class="popular-shows__item">
# <a class="popular-shows__link" href="/shows/the-lion-king/">
#                     The Lion King
#                 </a>
# </li>
# <li class="popular-shows__item">
# <a class="popular-shows__link" href="/shows/to-kill-mockingbird/">
#                     To Kill a Mockingbird
#                 </a>
# </li>
# <li class="popular-shows__item">
# <a class="popular-shows__link" href="/shows/hamilton-broadway/">
#                     Hamilton
#                 </a>
# </li>
# <li class="popular-shows__item">
# <a class="popular-shows__link" href="/shows/hadestown/">
#                     Hadestown
#                 </a>
# </li>
# <li class="popular-shows__item">
# <a class="popular-shows__link" href="/shows/chicago/">
#                     Chicago
#                 </a>
# </li>
# <li class="popular-shows__item">
# <a class="popular-shows__link" href="/shows/waitress/">
#                     Waitress
#                 </a>
# </li>
# <li class="popular-shows__item">
# <a class="popular-shows__link" href="/shows/tina-tina-turner-musical/">
#                     Tina: The Tina Turner Musical
#                 </a>
# </li>
# <li class="popular-shows__item">
# <a class="popular-shows__link" href="/shows/music-man/">
#                     The Music Man
#                 </a>
# </li>
# <li class="popular-shows__item">
# <a class="popular-shows__link" href="/shows/david-byrnes-american-utopia/">
#                     David Byrne's American Utopia
#                 </a>
# </li>
# <li class="popular-shows__item">
# <a class="popular-shows__link" href="/shows/aladdin-broadway/">
#                     Aladdin
#                 </a>
# </li>
# <li class="popular-shows__item">
# <a class="popular-shows__link" href="/shows/come-away/">
#                     Come From Away
#                 </a>
# </li>
# <li class="popular-shows__item">
# <a class="popular-shows__link" href="/shows/the-phantom-of-the-opera/">
#                     The Phantom of the Opera
#                 </a>
# </li>
# <li class="popular-shows__item">
# <a class="popular-shows__link" href="/shows/harry-potter-and-cursed-child-broadway/">
#                     Harry Potter and the Cursed Child
#                 </a>
# </li>
# <li class="popular-shows__item">
# <a class="popular-shows__link" href="/shows/book-mormon/">
#                     The Book of Mormon
#                 </a>
# </li>
# <li class="popular-shows__item">
# <a class="popular-shows__link" href="/shows/aint-too-proud/">
#                     Ain't Too Proud
#                 </a>
# </li>
# <li class="popular-shows__item">
# <a class="popular-shows__link" href="/shows/mrs-doubtfire/">
#                     Mrs. Doubtfire
#                 </a>
# </li>
# <li class="popular-shows__item">
# <a class="popular-shows__link" href="/shows/jagged-little-pill/">
#                     Jagged Little Pill
#                 </a>
# </li>
# <li class="popular-shows__item">
# <a class="popular-shows__link" href="/shows/dear-evan-hansen/">
#                     Dear Evan Hansen
#                 </a>
# </li>
# <li class="popular-shows__item">
# <a class="popular-shows__link" href="/shows/diana/">
#                     Diana
#                 </a>
# </li>
# <li class="popular-shows__item">
# <a class="popular-shows__link" href="/shows/girl-north-from-the-country/">
#                     Girl From the North Country
#                 </a>
# </li>
# <li class="popular-shows__item">
# <a class="popular-shows__link" href="/shows/mj/">
#                     MJ The Musical
#                 </a>
# </li>
# <li class="popular-shows__item">
# <a class="popular-shows__link" href="/shows/company/">
#                     Company
#                 </a>
# </li>
# </ol>
# <ol class="hidden-sm">
# <li class="popular-shows__item">
# <a class="popular-shows__link" href="/shows/moulin-rouge-musical/">
#                     Moulin Rouge! The Musical
#                 </a>
# </li>
# <li class="popular-shows__item">
# <a class="popular-shows__link" href="/shows/wicked/">
#                     Wicked
#                 </a>
# </li>
# <li class="popular-shows__item">
# <a class="popular-shows__link" href="/shows/the-lion-king/">
#                     The Lion King
#                 </a>
# </li>
# <li class="popular-shows__item">
# <a class="popular-shows__link" href="/shows/to-kill-mockingbird/">
#                     To Kill a Mockingbird
#                 </a>
# </li>
# <li class="popular-shows__item">
# <a class="popular-shows__link" href="/shows/hamilton-broadway/">
#                     Hamilton
#                 </a>
# </li>
# <li class="popular-shows__item">
# <a class="popular-shows__link" href="/shows/hadestown/">
#                     Hadestown
#                 </a>
# </li>
# <li class="popular-shows__item">
# <a class="popular-shows__link" href="/shows/chicago/">
#                     Chicago
#                 </a>
# </li>
# <li class="popular-shows__item">
# <a class="popular-shows__link" href="/shows/waitress/">
#                     Waitress
#                 </a>
# </li>
# <li class="popular-shows__item">
# <a class="popular-shows__link" href="/shows/tina-tina-turner-musical/">
#                     Tina: The Tina Turner Musical
#                 </a>
# </li>
# <li class="popular-shows__item">
# <a class="popular-shows__link" href="/shows/music-man/">
#                     The Music Man
#                 </a>
# </li>
# </ol>
# </div>

# %%
shows = scraped.find('div', class_='popular-shows__list-items')

# %% [markdown]
# As stated above, json is the perfect library to hand this situation. As we can see below, now all we need to do is parse through a dictionary of the show's information. Now we can get the name of the show as well as the url.

# %%
json.loads("".join(shows.find("script", {"type":"application/ld+json"}).contents))
# Out:
# {'@context': 'http://schema.org',
#  '@type': 'ItemList',
#  'itemListElement': [{'@type': 'ListItem',
#    'position': 1,
#    'name': 'Moulin Rouge! The Musical',
#    'url': 'https://broadway.com/shows/moulin-rouge-musical/'},
#   {'@type': 'ListItem',
#    'position': 2,
#    'name': 'Wicked',
#    'url': 'https://broadway.com/shows/wicked/'},
#   {'@type': 'ListItem',
#    'position': 3,
#    'name': 'The Lion King',
#    'url': 'https://broadway.com/shows/the-lion-king/'},
#   {'@type': 'ListItem',
#    'position': 4,
#    'name': 'To Kill a Mockingbird',
#    'url': 'https://broadway.com/shows/to-kill-mockingbird/'},
#   {'@type': 'ListItem',
#    'position': 5,
#    'name': 'Hamilton',
#    'url': 'https://broadway.com/shows/hamilton-broadway/'},
#   {'@type': 'ListItem',
#    'position': 6,
#    'name': 'Hadestown',
#    'url': 'https://broadway.com/shows/hadestown/'},
#   {'@type': 'ListItem',
#    'position': 7,
#    'name': 'Chicago',
#    'url': 'https://broadway.com/shows/chicago/'},
#   {'@type': 'ListItem',
#    'position': 8,
#    'name': 'Waitress',
#    'url': 'https://broadway.com/shows/waitress/'},
#   {'@type': 'ListItem',
#    'position': 9,
#    'name': 'Tina: The Tina Turner Musical',
#    'url': 'https://broadway.com/shows/tina-tina-turner-musical/'},
#   {'@type': 'ListItem',
#    'position': 10,
#    'name': 'The Music Man',
#    'url': 'https://broadway.com/shows/music-man/'},
#   {'@type': 'ListItem',
#    'position': 11,
#    'name': "David Byrne's American Utopia",
#    'url': 'https://broadway.com/shows/david-byrnes-american-utopia/'},
#   {'@type': 'ListItem',
#    'position': 12,
#    'name': 'Aladdin',
#    'url': 'https://broadway.com/shows/aladdin-broadway/'},
#   {'@type': 'ListItem',
#    'position': 13,
#    'name': 'Come From Away',
#    'url': 'https://broadway.com/shows/come-away/'},
#   {'@type': 'ListItem',
#    'position': 14,
#    'name': 'The Phantom of the Opera',
#    'url': 'https://broadway.com/shows/the-phantom-of-the-opera/'},
#   {'@type': 'ListItem',
#    'position': 15,
#    'name': 'Harry Potter and the Cursed Child',
#    'url': 'https://broadway.com/shows/harry-potter-and-cursed-child-broadway/'},
#   {'@type': 'ListItem',
#    'position': 16,
#    'name': 'The Book of Mormon',
#    'url': 'https://broadway.com/shows/book-mormon/'},
#   {'@type': 'ListItem',
#    'position': 17,
#    'name': "Ain't Too Proud – The Life and Times of The Temptations",
#    'url': 'https://broadway.com/shows/aint-too-proud/'},
#   {'@type': 'ListItem',
#    'position': 18,
#    'name': 'Mrs. Doubtfire',
#    'url': 'https://broadway.com/shows/mrs-doubtfire/'},
#   {'@type': 'ListItem',
#    'position': 19,
#    'name': 'Jagged Little Pill',
#    'url': 'https://broadway.com/shows/jagged-little-pill/'},
#   {'@type': 'ListItem',
#    'position': 20,
#    'name': 'Dear Evan Hansen',
#    'url': 'https://broadway.com/shows/dear-evan-hansen/'},
#   {'@type': 'ListItem',
#    'position': 21,
#    'name': 'Diana',
#    'url': 'https://broadway.com/shows/diana/'},
#   {'@type': 'ListItem',
#    'position': 22,
#    'name': 'Girl From the North Country',
#    'url': 'https://broadway.com/shows/girl-north-from-the-country/'},
#   {'@type': 'ListItem',
#    'position': 23,
#    'name': 'MJ The Musical',
#    'url': 'https://broadway.com/shows/mj/'},
#   {'@type': 'ListItem',
#    'position': 24,
#    'name': 'Company',
#    'url': 'https://broadway.com/shows/company/'}]}

# %%
#The top line is the same code as above, just renamed as a variable.
all_shows = json.loads("".join(shows.find("script", {"type":"application/ld+json"}).contents))

top_shows = all_shows['itemListElement']

# %%
top_shows
# Out:
# [{'@type': 'ListItem',
#   'position': 1,
#   'name': 'Moulin Rouge! The Musical',
#   'url': 'https://broadway.com/shows/moulin-rouge-musical/'},
#  {'@type': 'ListItem',
#   'position': 2,
#   'name': 'Wicked',
#   'url': 'https://broadway.com/shows/wicked/'},
#  {'@type': 'ListItem',
#   'position': 3,
#   'name': 'The Lion King',
#   'url': 'https://broadway.com/shows/the-lion-king/'},
#  {'@type': 'ListItem',
#   'position': 4,
#   'name': 'To Kill a Mockingbird',
#   'url': 'https://broadway.com/shows/to-kill-mockingbird/'},
#  {'@type': 'ListItem',
#   'position': 5,
#   'name': 'Hamilton',
#   'url': 'https://broadway.com/shows/hamilton-broadway/'},
#  {'@type': 'ListItem',
#   'position': 6,
#   'name': 'Hadestown',
#   'url': 'https://broadway.com/shows/hadestown/'},
#  {'@type': 'ListItem',
#   'position': 7,
#   'name': 'Chicago',
#   'url': 'https://broadway.com/shows/chicago/'},
#  {'@type': 'ListItem',
#   'position': 8,
#   'name': 'Waitress',
#   'url': 'https://broadway.com/shows/waitress/'},
#  {'@type': 'ListItem',
#   'position': 9,
#   'name': 'Tina: The Tina Turner Musical',
#   'url': 'https://broadway.com/shows/tina-tina-turner-musical/'},
#  {'@type': 'ListItem',
#   'position': 10,
#   'name': 'The Music Man',
#   'url': 'https://broadway.com/shows/music-man/'},
#  {'@type': 'ListItem',
#   'position': 11,
#   'name': "David Byrne's American Utopia",
#   'url': 'https://broadway.com/shows/david-byrnes-american-utopia/'},
#  {'@type': 'ListItem',
#   'position': 12,
#   'name': 'Aladdin',
#   'url': 'https://broadway.com/shows/aladdin-broadway/'},
#  {'@type': 'ListItem',
#   'position': 13,
#   'name': 'Come From Away',
#   'url': 'https://broadway.com/shows/come-away/'},
#  {'@type': 'ListItem',
#   'position': 14,
#   'name': 'The Phantom of the Opera',
#   'url': 'https://broadway.com/shows/the-phantom-of-the-opera/'},
#  {'@type': 'ListItem',
#   'position': 15,
#   'name': 'Harry Potter and the Cursed Child',
#   'url': 'https://broadway.com/shows/harry-potter-and-cursed-child-broadway/'},
#  {'@type': 'ListItem',
#   'position': 16,
#   'name': 'The Book of Mormon',
#   'url': 'https://broadway.com/shows/book-mormon/'},
#  {'@type': 'ListItem',
#   'position': 17,
#   'name': "Ain't Too Proud – The Life and Times of The Temptations",
#   'url': 'https://broadway.com/shows/aint-too-proud/'},
#  {'@type': 'ListItem',
#   'position': 18,
#   'name': 'Mrs. Doubtfire',
#   'url': 'https://broadway.com/shows/mrs-doubtfire/'},
#  {'@type': 'ListItem',
#   'position': 19,
#   'name': 'Jagged Little Pill',
#   'url': 'https://broadway.com/shows/jagged-little-pill/'},
#  {'@type': 'ListItem',
#   'position': 20,
#   'name': 'Dear Evan Hansen',
#   'url': 'https://broadway.com/shows/dear-evan-hansen/'},
#  {'@type': 'ListItem',
#   'position': 21,
#   'name': 'Diana',
#   'url': 'https://broadway.com/shows/diana/'},
#  {'@type': 'ListItem',
#   'position': 22,
#   'name': 'Girl From the North Country',
#   'url': 'https://broadway.com/shows/girl-north-from-the-country/'},
#  {'@type': 'ListItem',
#   'position': 23,
#   'name': 'MJ The Musical',
#   'url': 'https://broadway.com/shows/mj/'},
#  {'@type': 'ListItem',
#   'position': 24,
#   'name': 'Company',
#   'url': 'https://broadway.com/shows/company/'}]

# %%
#Now we will parse through the nested dictionary above to get the information we're looking for.
show_dict = {}
for show in top_shows:
    show_dict[show['name']] = show['url']

# %%
#This is a list of urls that we will visit
urls = list(show_dict.values())

# %% [markdown]
# The code below shows an example of what we will do for ALL of the url links. By visiting each one, we will be able to extract the information similar to how we did above.

# %%
response = requests.get(urls[0])
html = response.content
scraped = BeautifulSoup(html, 'html.parser')
    
scraped.find('div', class_='rspCalendar__cellGrid')
# Out:
# <div class="rspCalendar__cellGrid">
# <script type="application/ld+json">{"@context": "http://schema.org", "@type": "TheaterEvent", "name": "Moulin Rouge! The Musical - Broadway Tickets", "description": "A theatrical celebration of truth, beauty, freedom and love.", "image": "https://imaging.broadway.com/images/widescreen-169/w1920/120034-15.jpg", "location": {"@type": "Place", "name": "Al Hirschfeld Theatre", "address": {"@type": "PostalAddress", "streetAddress": "302 West 45th Street", "AddressCountry": "US", "addressLocality": "New York", "addressRegion": "NY", "postalCode": "10036"}, "url": "https://www.broadway.com/venues/theaters/al-hirschfeld-theatre/"}, "offers": {"@type": "Offer", "url": "https://www.broadway.com/shows/moulin-rouge-musical/", "price": "69.00", "priceCurrency": "USD", "availability": "http://schema.org/InStock", "validFrom": "2019-07-25"}, "startDate": "2021-10-15T19:00:00-04:00", "endDate": "2021-10-15", "performers": {"@type": "TheaterGroup", "name": "Moulin Rouge! The Musical - New York", "url": "https://www.broadway.com/shows/moulin-rouge-musical/"}, "eventAttendanceMode": "OfflineEventAttendanceMode", "eventStatus": "https://schema.org/EventScheduled"}</script>
# <div class="rspCalendar__unavailableButton">
#                                     7:00pm
#                                     <br/>
#                                     Sold Out
#                                 </div>
# </div>

# %% [markdown]
# The code below will allow us to travel to each of the webpages for the top 25 broadway shows, parse the information, and grab the show name, theatre name, and the price of a ticket.

# %%
show_list = []
description = []
theatre_name = []
price_list = []

for url in urls:
    response = requests.get(url)
    html = response.content
    scraped = BeautifulSoup(html, 'html.parser')
    
    info = scraped.find('div', class_='rspCalendar__cellGrid')
    info = json.loads("".join(info.find("script", {"type":"application/ld+json"}).contents))
    
    show_list.append(info['name'].split('-')[0])
    description.append(info['description'])
    theatre_name.append(info['location']['name'])
    price_list.append(info['offers']['price'])

# %% [markdown]
# Now that we have all of the information we are looking for in list form, we can easily put this into a DataFrame.

# %%
broadway = pd.DataFrame({'Shows': show_list, 'Description': description, 'Theater': theatre_name, 'Current Ticket Cost': price_list})

# %%
broadway
# Out:
#                                                 Shows  \
# 0                          Moulin Rouge! The Musical
# 1                                             Wicked
# 2                                      The Lion King
# 3                              To Kill a Mockingbird
# 4                                           Hamilton
# 5                                          Hadestown
# 6                                            Chicago
# 7                                           Waitress
# 8                      Tina: The Tina Turner Musical
# 9                                      The Music Man
# 10                     David Byrne's American Utopia
# 11                                           Aladdin
# 12                                    Come From Away
# 13                          The Phantom of the Opera
# 14                 Harry Potter and the Cursed Child
# 15                                The Book of Mormon
# 16  Ain't Too Proud – The Life and Times of The Te...
# 17                                    Mrs. Doubtfire
# 18                                Jagged Little Pill
# 19                                  Dear Evan Hansen
# 20                                             Diana
# 21                       Girl From the North Country
# 22                                    MJ The Musical
# 23                                           Company
#
#                                           Description  \
# 0   A theatrical celebration of truth, beauty, fre...
# 1   Meet the witches of Oz before Dorothy dropped in.
# 2   Pride Rock comes to life in Disney’s long-runn...
# 3   Harper Lee’s classic courtroom drama comes to ...
# 4    A fresh look at the era of the Founding Fathers.
# 5   The Tony-winning musical that follows the myth...
# 6   The Tony-winning revival of Kander and Ebb’s m...
# 7   Sara Bareilles’ score and creatively titled pi...
# 8   The story of the legendary Tina Turner is now ...
# 9   Hugh Jackman returns to Broadway as Harold Hil...
# 10  David Byrne’s innovative and acclaimed theatri...
# 11  The beloved Disney story is brought to thrilli...
# 12  When the world stopped, their stories moved us...
# 13  This lush romantic smash is Broadway’s longest...
# 14  Experience J.K. Rowling’s magical universe lik...
# 15     The nine-time Tony Award-winning Best Musical.
# 16  The electrifying musical hit that tells the st...
# 17  A new musical comedy about the things we do to...
# 18  A musical inspired by Alanis Morissette’s awar...
# 19  A deeply personal musical about life and the w...
# 20  The acclaimed bio-musical that tells the story...
# 21  Conor McPherson's acclaimed new work features ...
# 22  The life story of Michael Jackson arrives on B...
# 23  A revelatory staging of the quintessential Son...
#
#                       Theater Current Ticket Cost
# 0       Al Hirschfeld Theatre               69.00
# 1            Gershwin Theatre               89.00
# 2            Minskoff Theatre               75.00
# 3             Shubert Theatre               29.00
# 4     Richard Rodgers Theatre              149.00
# 5         Walter Kerr Theatre               49.00
# 6          Ambassador Theatre               49.50
# 7     Ethel Barrymore Theatre               79.00
# 8       Lunt-Fontanne Theatre               79.00
# 9       Winter Garden Theatre               99.00
# 10          St. James Theatre               59.00
# 11      New Amsterdam Theatre               57.50
# 12         Schoenfeld Theatre               49.00
# 13           Majestic Theatre               29.00
# 14              Lyric Theatre               79.00
# 15     Eugene O'Neill Theatre               69.00
# 16           Imperial Theatre               39.00
# 17   Stephen Sondheim Theatre               49.00
# 18         Broadhurst Theatre               49.00
# 19          Music Box Theatre               89.00
# 20           Longacre Theatre               49.00
# 21            Belasco Theatre               39.00
# 22         Neil Simon Theatre               59.00
# 23  Bernard B. Jacobs Theatre               59.00
